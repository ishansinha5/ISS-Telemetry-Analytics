# %%
# Import our custom logic from the scripts folder
import sys
sys.path.append('./scripts') # Change 'scripts' to 'src' if you used that folder name
import telemetry_utils as tu

# Run the function on our raw data
flyover_count = tu.count_michigan_flyovers('./data/iss_data.csv')
print(f"Total data points recorded over Michigan: {flyover_count}")
# Out:
# Total data points recorded over Michigan: 7
